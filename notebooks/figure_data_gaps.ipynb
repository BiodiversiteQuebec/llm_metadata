# %%
data = [
    {'Species Group': 'Mammals', 'Estimated Species': 100, 'GBIF': 50, 'GBIF + Partnership': 50},
    {'Species Group': 'Birds', 'Estimated Species': 80, 'GBIF': 40, 'GBIF + Partnership': 40},
    {'Species Group': 'Reptiles', 'Estimated Species': 60, 'GBIF': 30, 'GBIF + Partnership': 30},
    {'Species Group': 'Amphibians', 'Estimated Species': 120, 'GBIF': 60, 'GBIF + Partnership': 60},
    {'Species Group': 'Ray-finned Fish', 'Estimated Species': 40, 'GBIF': 20, 'GBIF + Partnership': 20},
    {'Species Group': 'Mollusca', 'Estimated Species': 20, 'GBIF': 10, 'GBIF + Partnership': 10},
    {'Species Group': 'Arachnids', 'Estimated Species': 30, 'GBIF': 15, 'GBIF + Partnership': 15},
    {'Species Group': 'Insects', 'Estimated Species': 50, 'GBIF': 25, 'GBIF + Partnership': 25},
    {'Species Group': 'Plants', 'Estimated Species': 90, 'GBIF': 45, 'GBIF + Partnership': 45},
    {'Species Group': 'Fungi', 'Estimated Species': 70, 'GBIF': 35, 'GBIF + Partnership': 35}
]

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


# Create a dataframe
sns.set_theme(style="whitegrid")
sns.barplot(x="Species Group", y="GBIF", data=df, color="green", alpha=0.5)
sns.barplot(x="Species Group", y="GBIF + Partnership", data=df, color="orange", alpha=0.5)

# Legend
legend_labels = ['Estimated Species', 'GBIF', 'GBIF + Partnership']
legend_handles = [plt.Rectangle((0, 0), 1, 1, color='blue', alpha=0.5),
                  plt.Rectangle((0, 0), 1, 1, color='green', alpha=0.5),
                  plt.Rectangle((0, 0), 1, 1, color='orange', alpha=0.5)]
plt.legend(legend_handles, legend_labels)

# Title and labels
plt.title("Biodiversity Data Gaps")
plt.xlabel("Species Group")
plt.ylabel("% of Species")

# Show the plot
plt.show()
# Out:
# c:\Users\beav3503\Miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\beav3503\Miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\beav3503\Miniconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
